# %% [markdown]
# <a href="https://colab.research.google.com/github/lidjud/Python-sem-23_1/blob/main/elementos_basicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![elementos básicos de PROGRAMACIÓN (1).jpg](data:image/jpeg;base64,...)

# %%
# %%html
# <marquee style='width: 50%; color: blue;'><b>Bienvenidos a su primera clase de programación con Python! 🧁 🦭 ✨ </b></marquee>
# Out:
# <marquee style='width: 50%; color: blue;'><b>Bienvenidos a su primera clase de programación con Python! 🧁 🦭 ✨ </b></marquee>

# %% [markdown]
# # Función print()

# %% [markdown]
# En el contexto de la programación, una **función** es una subrutina o subprograma que permite resolver una tarea especifica.
#
# Iniciaremos con la declaración de una función muy sencilla, la función ```print()```. Esta función imprime el valor que encuentra entre los paréntesis ("texto" o número).
#
# Además de los parentésis, agregamos comilla doble o sencilla para indicar que lo que está entre comillas, no es código.
#
# En la siguiente línea de código, escribe el mensaje Hello world! entre las comillas y ejecútala.

# %% [markdown]
# Declara algunas variables

# %%
a = 3

# %%
b = 2 * a

# %%
type(b)

# %%
print(b)

# %%
a * b

# %%
b = 'hello'

# %%
type(b)

# %%
b + b

# %%
2 * b

# %%
print("Hello word!\nHello word\nHello word")

# %%
print("Hello" + "students")

# %%
print("Cada vez que pienso en ti, 🤔 \
mis ojos rompen en llanto; 😢 \
y muy triste me pregunto, 😕 \
¿por qué te quiero tanto? 💘 :Cupid Arrow")
# Out:
# Cada vez que pienso en ti, 🤔 mis ojos rompen en llanto; 😢 y muy triste me pregunto, 😕 ¿por qué te quiero tanto? 💘 :Cupid Arrow

# %% [markdown]
# # Tipos de datos numéricos

# %% [markdown]
# ## Integer

# %%
1 + 1

# %%
a = 4

# %%
type(a)

# %% [markdown]
# ## Floats

# %%
c = 2.1
type(c)

# %% [markdown]
# ## Complex

# %%
a = 1.5 + 0.5j

# %%
a.real

# %%
a.imag

# %%
type(1. + 0j)

# %% [markdown]
# ## Booleans

# %%
3 > 4

# %%
test = (3 > 4)

# %%
test

# %%
type(test)

# %%
7 * 3

# %%
2 ** 10

# %%
8 % 3

# %%
#Conversión de tipo}
float(1)

# %%
a = 3
b = 2
type(a/b)

# %% [markdown]
# # Función input()

# %% [markdown]
# La función ```input()``` es para solicitar al usuario que introduzca algo a través del teclado (entrada estándar).

# %%
input("¿Cual es tu nombre?")

# %% [markdown]
# Observa lo que sucede cuando anidas las funciones ```input()``` y ```print()```.

# %%
print("Hola " + input(" ¿Cuál es tu nombre ?"))
# Out:
# ¿Cuál es tu nombre ?Lidia
# Hola Lidia

# %% [markdown]
# ## Comentarios en el código

# %% [markdown]
# Puedes escribir comentarios en tu código y que el ordenador lo ignore por completo. Para ello, utiliza el símbolo ```#```.
#
# Esto te permite escribir notas y documentar tu código sin afectar el programa.
#
# También puedes hacer comentarios que se extienden por múltiples líneas encerrando el texto entre ```'''```.
#
# Ejecuta la siguiente línea de código, ¿obtienes alguna salida?

# %%
#Este es un comentario de una solo línea

# %%
"""
Comentario en Python con
múltiples líneas en el
código
"""

print("🚨 Los comentarios no se imprimen")

# %% [markdown]
# Escribir comentarios en nuestro código, nos ayudar a recordar lo que está pasando en él.

# %%
# input() recibe una entrada del usuario
# Entonces print() imprime la palabra  Hola y la entrada del usuario con el signo de admiración
# También puedes seleccionar todos las filas y utilizar "Ctrl+z" para comentar las líneas seleccionadas.

print("Hola " + input("¿Cuál es tu nombre? ") + "!")

# %% [markdown]
# # Flujos de control

# %% [markdown]
# ## Condicionales
#
# Cuando escribes un programa, a veces es necesario ejecutar alguna secuencia de código únicamente cuando se cumple cierta condición. Para hacer esto, es necesario escribir una sentencia condicional o sentencia ```if```.
#
# En python, la primera parte de una sentencia condicional está formada por la palabra reservada ```if``` seguida de una expresión booleana. Una expresión booleana, es un tipo de expresión que solo podrá tomar dos valores, verdadero (```True```) o falso (```False```). En una sentencia if, la secuencia de código se ejecutará solamente cuando la expresión boolean devuelva un valor de True.
#
# ```
# # Una condicional básica.
# if 5==5:
#   #Codigo se ejecuta porque 5 es igual a 5 (True)
#   #bloque de codigo aqui
# ```

# %% [markdown]
# ###**Be careful!**

# %% [markdown]
# ## Identación de bloques
# En python, ¡la identación es importante!. Cada bloque o secuencia de código es identificado por medio de su identación. Después de escribir una condicional, _ciclo_ o _función_, deberás identar el bloque de código que quieres que esté dentro de ésta.
#
# Para identar los bloques de código, puedes utilizar tabulaciones o espacios. Intenta ser constante en el tipo de identación que uses.

# %% [markdown]
# Respeta la profundidad de la sangría ✍ ❕❕
#
# El shell de Colab aumenta automáticamente la profundidad de la sangría después de dos puntos: signo.

# %%
a = 10

if a == 1:
  print(1)
elif a == 2:
  print(2)
else:
  print('A lot')

# %% [markdown]
# ## Operadores relacionales
# Los siguientes operadores relacionales pueden ser utilizados para realizar comparaciones entre variables en una sentencia condicional.
#
# ```
# x == y #equivalente a: True si el valor de x es igual al de y
#
# x != y #diferente a: True si el valor de x es diferente al de y
#
# x < y #menor a: True si el valor de x es menor al de y
#
# x > y #mayor a: True si el valor de x es mayor al de y
#
# x <= y #menor o igual a: True si el valor de x es menor o igual al de y
#
# x >= y #mayor o igual a: True si el valor de x es mayor o igual al de y
# ```

# %%
#Una expresion booleana con valor True
print(5 == 5)
if 5 == 5:
    print("El valor es verdadero!")

#Una expresion booleana con valor False
print(4 == 5)
if 4 == 5:
    print("El valor es falso!")

# %% [markdown]
# ## Condicionales en cadena y anidadas
#
# A veces es necesario evaluar más de una posibilidad mediante condicionales, podrás utilizar ```elif``` (de else if) para para hacerlo.
#
# ```
# if cond1:
#   #secuencia 1
# elif cond2:
#   #secuencia 2
# ...
# elif condn:
#   #secuencia n
# else:
#   #ultima secuencia
# ```

# %%
#condicionales anidadas
#Prueba a cambiar los valores de x, y
x = 5
y = 10

if x == y:
    print(x, 'es igual a', y)
else:
    if x > y:
        print(x, 'es mayor que ', y)
    else:
        print(x, 'es menor que ', y)

# %% [markdown]
# ## Operadores lógicos
#
# Puedes combinar múltiples expresiones booleanas haciendo uso de operadores lógicos. Los siguientes tres operadores lógicos están disponibles en Python:
#
#
# * **and**
#
#   > Verdadero si ambas expresiones son verdaderas.
# * **or**
#
#   > Verdadero si una de las expresiones es verdadera o ambas lo son.
# * **not**
#
#   > Negación de la expresión, regresa falso si la expresión es verdadera o verdadero si la expresión es falsa.

# %%
#Prueba cambiando el valor de x
x = 5
if x > 0 and x < 10:
    print(x, " es un valor entre 0 y 10")

# %%
#Prueba cambiando el valor de x
x = 6
if (x % 2 == 0) or (x % 3 == 0):
    print(x, "es un numero divisible entre tres o dos o ambos")

# %%
#Prueba cambiando el valor de x
x = 5
if not(x > 10):
    print(x, " es un número menor o igual a 10")

# %%
#condicionales en cadena
#Prueba a cambiar los valores de x, y
x = 5
y = 10

if x < y:
    print(x, 'es menor que ', y)
elif x > y:
    print(x, 'es mayor que ', y)
else:
    print(x, 'es igual a', y)

# %%
#condicionales anidadas
#Prueba a cambiar los valores de x, y
x = 5
y = 10

if x == y:
    print(x, 'es igual a', y)
else:
    if x > y:
        print(x, 'es mayor que ', y)
    else:
        print(x, 'es menor que ', y)

# %%
"""
Práctica 1
"""

"""
Verifica si una cadena tiene la misma cantidad de 't' y 'g'. 

El método debe devolver un valor booleano y no distinguir entre mayúsculas y minúsculas. La cadena puede contener cualquier caracter.

Ejemplos de entrada/salida:

("ttgg") => true
("tggtt") => false
("ggtTm") => true
("cococoo") => true // cuando no encuentra 't' and 'g' retorna un valor true
("zzgg") => false
"""

def check_t_g_amount(input_str): # Creando una función
    var_bool = 'false' #bandera de valor
    
    '''
    Algoritmo:
        Paso 1: Crea una variable para contar la letra 't' y, otra variable para la letra 'g'. Inicializa sus valores con cero.
        Paso 2: Investiga un método que transforme en minúscula cualquier entrada de una letra.
                Puedes apoyarte en el siguiente enlace: https://www.w3schools.com/python/ref_string_lower.asp
        Paso 3: Convierte en una lista, llamada str_list, la entrada de la cadena de texto. 
                Puedes apoyarte googleando la siguiente pregunta: how to converte a string into a list with python stack overflow.
        Paso 4: Verifica con una llave la cantidad de 't's y 'g's, cuenta sus valores.
        Paso 5: Retorno basado en la igualdad.
    '''
    #Inicializa el valor de las variables
    t_count = 
    g_count = 
    
    #Convierte en minúsculas la cadena que recibe 
    input_str =

    #Convierte la cadena en una lista
    str_list = 

    for char in str_list:
        if char == 't':
            #cuentas los valores de 't'

        elif char == 'g':
            #cuentas los valores de 'g'

        else:
            pass
    
    if  t_count == g_count:
        var_bool = 'true'
    else:
        pass
    
    return var_bool

# %%
print(check_t_g_amount('ggtt'))
print(check_t_g_amount('tggtt'))
print(check_t_g_amount('ootTm'))
print(check_t_g_amount('zzgg'))
print(check_t_g_amount('zpzpzpp'))

# %%
"""
Práctica 2
"""

"""
Dada una lista de precios enteros que representan los precios de ropa de una tienda de autoservicios y un presupuesto k, devuelve el número máximo de prendas que un usuario puede comprar.

Ejemplo
Entrada
precios = [90, 30, 20, 40, 90]
k = 95
Producción
3
Explicación
Podemos comprar las prendas con los precios 30, 20 y 40.
"""
